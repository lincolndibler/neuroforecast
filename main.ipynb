# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append('/content/drive/My Drive/neuroforecast')

# %%
from predictionapi import app
import uvicorn

# %%
if __name__ == "__main__":
    uvicorn.run(app, host="0.0.0.0", port=8000)
